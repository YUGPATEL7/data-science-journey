# %%
import pandas as pd

# %%
df = pd.read_excel(
    r"D:\data-science-journey\Data_Science\Data\Pandas_Student_Analytics_Dataset.xlsx",
    engine="openpyxl"
)

# %%
df.head(10)
df.tail(10)
# Out:
#      StudentID EnrollmentNo      StudentName  Gender  Age         City  \
# 1190   STU1191  GTU26001191     Yash Trivedi    Male   22    Bhavnagar
# 1191   STU1192  GTU26001192    Aryan Trivedi    Male   18        Surat
# 1192   STU1193  GTU26001193  Krishna Solanki    Male   20      Mehsana
# 1193   STU1194  GTU26001194      Ananya Shah  Female   24       Rajkot
# 1194   STU1195  GTU26001195      Dhruv Desai    Male   19       Rajkot
# 1195   STU1196  GTU26001196      Rahul Joshi    Male   23       Rajkot
# 1196   STU1197  GTU26001197   Vivaan Panchal    Male   22    Bhavnagar
# 1197   STU1198  GTU26001198    Rahul Trivedi    Male   18  Gandhinagar
# 1198   STU1199  GTU26001199      Aryan Desai    Male   22   Himatnagar
# 1199   STU1200  GTU26001200     Yash Panchal    Male   21       Rajkot
#
#                          CollegeName              Department  Semester  \
# 1190  Government Engineering College              Electrical         8
# 1191  Government Engineering College  Information Technology         8
# 1192                   Alpha College                Computer         8
# 1193                   Alpha College             Electronics         5
# 1194                  LDRP Institute                   Civil         6
# 1195                   Alpha College                Computer         7
# 1196                   LJ University                Computer         6
# 1197                  LDRP Institute                   Civil         8
# 1198  Government Engineering College             Electronics         8
# 1199                  LDRP Institute                Computer         7
#
#      AdmissionDate  ...  Grade  Status  FeesTotal  FeesPaid  FeesDue  \
# 1190    2025-07-30  ...      C    Pass      40000     26790    13210
# 1191    2026-01-23  ...      A    Pass      45000     24872    20128
# 1192    2026-03-17  ...      A    Pass      25000     23462     1538
# 1193    2026-02-12  ...      A    Pass      40000     36521     3479
# 1194    2026-04-13  ...      A    Pass      30000     22960     7040
# 1195    2025-11-25  ...      B    Pass      25000     13627    11373
# 1196    2025-12-18  ...     A+    Pass      25000     23975     1025
# 1197    2026-03-27  ...      B    Pass      45000     30283    14717
# 1198    2025-11-02  ...      B    Pass      45000     41487     3513
# 1199    2026-01-07  ...      B    Pass      40000     30278     9722
#
#       Scholarship PlacementStatus InternshipPerformance  ProjectScore  \
# 1190          OBC  Higher Studies               Average            74
# 1191        SC/ST  Higher Studies             Excellent            52
# 1192        SC/ST     Seeking Job                  Good            84
# 1193          EWS          Placed                  Good            86
# 1194        SC/ST          Placed                  Good            87
# 1195          OBC     Seeking Job               Average            82
# 1196          OBC          Placed             Very Good            86
# 1197          EWS     Seeking Job             Very Good            56
# 1198        SC/ST  Higher Studies                  Good            95
# 1199          OBC  Higher Studies                  Good            80
#
#       Backlogs
# 1190         1
# 1191         2
# 1192         2
# 1193         0
# 1194         2
# 1195         1
# 1196         1
# 1197         1
# 1198         2
# 1199         2
#
# [10 rows x 26 columns]

# %%
df.shape
# Out:
# (1200, 26)

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StudentID              1200 non-null   object
#  1   EnrollmentNo           1200 non-null   object
#  2   StudentName            1200 non-null   object
#  3   Gender                 1200 non-null   object
#  4   Age                    1200 non-null   int64
#  5   City                   1200 non-null   object
#  6   CollegeName            1200 non-null   object
#  7   Department             1200 non-null   object
#  8   Semester               1200 non-null   int64
#  9   AdmissionDate          1200 non-null   object
#  10  AttendancePct          1200 non-null   int64
#  11  InternalMarks          1200 non-null   int64
#  12  PracticalMarks         1200 non-null   int64
#  13  FinalExamMarks         1200 non-null   int64
#  14  TotalMarks             1200 non-null   int64
#  15  Percentage             1200 non-null   int64
#  16  Grade                  1200 non-null   object
#  17  Status                 1200 non-null   object
#  18  FeesTotal              1200 non-null   int64
#  19  FeesPaid               1200 non-null   int64
#  20  FeesDue                1200 non-null   int64
#  21  Scholarship            974 non-null    object
#  22  PlacementStatus        1200 non-null   object
#  23  InternshipPerformance  1200 non-null   object
#  24  ProjectScore           1200 non-null   int64
#  25  Backlogs               1200 non-null   int64
# dtypes: int64(13), object(13)
# memory usage: 243.9+ KB

# %% [markdown]
# # Module 2

# %%
df.memory_usage(deep=True)
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StudentID              1200 non-null   object
#  1   EnrollmentNo           1200 non-null   object
#  2   StudentName            1200 non-null   object
#  3   Gender                 1200 non-null   object
#  4   Age                    1200 non-null   int64
#  5   City                   1200 non-null   object
#  6   CollegeName            1200 non-null   object
#  7   Department             1200 non-null   object
#  8   Semester               1200 non-null   int64
#  9   AdmissionDate          1200 non-null   object
#  10  AttendancePct          1200 non-null   int64
#  11  InternalMarks          1200 non-null   int64
#  12  PracticalMarks         1200 non-null   int64
#  13  FinalExamMarks         1200 non-null   int64
#  14  TotalMarks             1200 non-null   int64
#  15  Percentage             1200 non-null   int64
#  16  Grade                  1200 non-null   object
#  17  Status                 1200 non-null   object
#  18  FeesTotal              1200 non-null   int64
#  19  FeesPaid               1200 non-null   int64
#  20  FeesDue                1200 non-null   int64
#  21  Scholarship            974 non-null    object
#  22  PlacementStatus        1200 non-null   object
#  23  InternshipPerformance  1200 non-null   object
#  24  ProjectScore           1200 non-null   int64
#  25  Backlogs               1200 non-null   int64
# dtypes: int64(13), object(13)
# memory usage: 1.1 MB

# %%
# df.select_dtypes(include=['number']).columns.to_list()
df.select_dtypes(include=['object','category']).columns.to_list()
# Out:
# ['StudentID',
#  'EnrollmentNo',
#  'StudentName',
#  'Gender',
#  'City',
#  'CollegeName',
#  'Department',
#  'AdmissionDate',
#  'Grade',
#  'Status',
#  'Scholarship',
#  'PlacementStatus',
#  'InternshipPerformance']

# %%
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Mehsana', 'Himatnagar', 'Rajkot', 'Gandhinagar',
#        'Bhavnagar', 'Vadodara', 'Surat', 'Patan', 'Junagadh'],
#       dtype=object)

# %% [markdown]
# # Module 3

# %%
df.isnull().sum()
# Out:
# StudentID                  0
# EnrollmentNo               0
# StudentName                0
# Gender                     0
# Age                        0
# City                       0
# CollegeName                0
# Department                 0
# Semester                   0
# AdmissionDate              0
# AttendancePct              0
# InternalMarks              0
# PracticalMarks             0
# FinalExamMarks             0
# TotalMarks                 0
# Percentage                 0
# Grade                      0
# Status                     0
# FeesTotal                  0
# FeesPaid                   0
# FeesDue                    0
# Scholarship              226
# PlacementStatus            0
# InternshipPerformance      0
# ProjectScore               0
# Backlogs                   0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      StudentID EnrollmentNo     StudentName  Gender  Age         City  \
# 0      STU0001  GTU26000001    Vivaan Desai    Male   24    Ahmedabad
# 1      STU0002  GTU26000002    Ananya Mehta  Female   18    Ahmedabad
# 2      STU0003  GTU26000003   Sneha Panchal  Female   20      Mehsana
# 3      STU0004  GTU26000004    Neha Solanki  Female   21   Himatnagar
# 4      STU0005  GTU26000005     Aarav Joshi    Male   20       Rajkot
# ...        ...          ...             ...     ...  ...          ...
# 1195   STU1196  GTU26001196     Rahul Joshi    Male   23       Rajkot
# 1196   STU1197  GTU26001197  Vivaan Panchal    Male   22    Bhavnagar
# 1197   STU1198  GTU26001198   Rahul Trivedi    Male   18  Gandhinagar
# 1198   STU1199  GTU26001199     Aryan Desai    Male   22   Himatnagar
# 1199   STU1200  GTU26001200    Yash Panchal    Male   21       Rajkot
#
#                          CollegeName              Department  Semester  \
# 0                 Marwadi University              Electrical         7
# 1                  Ganpat University             Electronics         8
# 2                      Alpha College  Information Technology         7
# 3              Silver Oak University              Mechanical         7
# 4                 Marwadi University              Electrical         5
# ...                              ...                     ...       ...
# 1195                   Alpha College                Computer         7
# 1196                   LJ University                Computer         6
# 1197                  LDRP Institute                   Civil         8
# 1198  Government Engineering College             Electronics         8
# 1199                  LDRP Institute                Computer         7
#
#      AdmissionDate  ...  Grade  Status  FeesTotal  FeesPaid  FeesDue  \
# 0       2025-11-22  ...      A    Pass      35000     17529    17471
# 1       2025-07-23  ...      C    Pass      45000     30373    14627
# 2       2025-06-07  ...     A+    Pass      25000     22595     2405
# 3       2026-03-11  ...     A+    Pass      30000     14706    15294
# 4       2026-04-24  ...      A    Pass      25000     24682      318
# ...            ...  ...    ...     ...        ...       ...      ...
# 1195    2025-11-25  ...      B    Pass      25000     13627    11373
# 1196    2025-12-18  ...     A+    Pass      25000     23975     1025
# 1197    2026-03-27  ...      B    Pass      45000     30283    14717
# 1198    2025-11-02  ...      B    Pass      45000     41487     3513
# 1199    2026-01-07  ...      B    Pass      40000     30278     9722
#
#       Scholarship PlacementStatus InternshipPerformance  ProjectScore  \
# 0           Merit          Placed                  Good            85
# 1             NaN     Seeking Job             Very Good            58
# 2             EWS  Higher Studies               Average            83
# 3             NaN     Seeking Job               Average            74
# 4             OBC     Seeking Job             Very Good            84
# ...           ...             ...                   ...           ...
# 1195          OBC     Seeking Job               Average            82
# 1196          OBC          Placed             Very Good            86
# 1197          EWS     Seeking Job             Very Good            56
# 1198        SC/ST  Higher Studies                  Good            95
# 1199          OBC  Higher Studies                  Good            80
#
#       Backlogs
# 0            2
# 1            0
# 2            3
# 3            2
# 4            3
# ...        ...
# 1195         1
# 1196         1
# 1197         1
# 1198         2
# 1199         2
#
# [1200 rows x 26 columns]

# %%
df['AttendancePct'].isnull().sum()
df['Scholarship'].fillna("None")
# Out:
# 0       Merit
# 1        None
# 2         EWS
# 3        None
# 4         OBC
#         ...
# 1195      OBC
# 1196      OBC
# 1197      EWS
# 1198    SC/ST
# 1199      OBC
# Name: Scholarship, Length: 1200, dtype: object

# %%
df['AdmissionDate']  = pd.to_datetime(df['AdmissionDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StudentID              1200 non-null   object
#  1   EnrollmentNo           1200 non-null   object
#  2   StudentName            1200 non-null   object
#  3   Gender                 1200 non-null   object
#  4   Age                    1200 non-null   int64
#  5   City                   1200 non-null   object
#  6   CollegeName            1200 non-null   object
#  7   Department             1200 non-null   object
#  8   Semester               1200 non-null   int64
#  9   AdmissionDate          1200 non-null   datetime64[ns]
#  10  AttendancePct          1200 non-null   int64
#  11  InternalMarks          1200 non-null   int64
#  12  PracticalMarks         1200 non-null   int64
#  13  FinalExamMarks         1200 non-null   int64
#  14  TotalMarks             1200 non-null   int64
#  15  Percentage             1200 non-null   int64
#  16  Grade                  1200 non-null   object
#  17  Status                 1200 non-null   object
#  18  FeesTotal              1200 non-null   int64
#  19  FeesPaid               1200 non-null   int64
#  20  FeesDue                1200 non-null   int64
#  21  Scholarship            974 non-null    object
#  22  PlacementStatus        1200 non-null   object
#  23  InternshipPerformance  1200 non-null   object
#  24  ProjectScore           1200 non-null   int64
#  25  Backlogs               1200 non-null   int64
# dtypes: datetime64[ns](1), int64(13), object(12)
# memory usage: 243.9+ KB

# %%
df.rename(columns={"AttendancePct": "Attendance"}, inplace=True)

# %% [markdown]
# # Module 4 - Student Analysis

# %%
len(df['StudentID'])
# Out:
# 1200

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      663
# Female    537
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(21.059166666666666)

# %%
df.loc[df['Age']==df['Age'].max(),['EnrollmentNo','StudentName']]
# Out:
#      EnrollmentNo       StudentName
# 0     GTU26000001      Vivaan Desai
# 13    GTU26000014     Rahul Panchal
# 14    GTU26000015  Vivaan Prajapati
# 22    GTU26000023     Sneha Trivedi
# 26    GTU26000027      Ishita Desai
# ...           ...               ...
# 1153  GTU26001154   Aarav Chaudhary
# 1157  GTU26001158    Aditya Trivedi
# 1161  GTU26001162     Nisha Solanki
# 1180  GTU26001181    Ananya Solanki
# 1193  GTU26001194       Ananya Shah
#
# [190 rows x 2 columns]

# %%
df.loc[df['Attendance'] >= 90,['EnrollmentNo','StudentName','Attendance']]
# Out:
#      EnrollmentNo        StudentName  Attendance
# 7     GTU26000008      Meera Trivedi         100
# 15    GTU26000016    Dhruv Prajapati          94
# 17    GTU26000018        Meera Patel          91
# 18    GTU26000019  Krishna Chaudhary          96
# 25    GTU26000026       Vivaan Patel          95
# ...           ...                ...         ...
# 1177  GTU26001178     Ishita Solanki          91
# 1189  GTU26001190     Aditya Panchal          90
# 1192  GTU26001193    Krishna Solanki          95
# 1196  GTU26001197     Vivaan Panchal          98
# 1197  GTU26001198      Rahul Trivedi          94
#
# [310 rows x 3 columns]

# %%
df.loc[df['Backlogs'] >= 2,['EnrollmentNo','StudentName','Backlogs']]
# Out:
#      EnrollmentNo      StudentName  Backlogs
# 0     GTU26000001     Vivaan Desai         2
# 2     GTU26000003    Sneha Panchal         3
# 3     GTU26000004     Neha Solanki         2
# 4     GTU26000005      Aarav Joshi         3
# 6     GTU26000007      Ishita Shah         2
# ...           ...              ...       ...
# 1191  GTU26001192    Aryan Trivedi         2
# 1192  GTU26001193  Krishna Solanki         2
# 1194  GTU26001195      Dhruv Desai         2
# 1198  GTU26001199      Aryan Desai         2
# 1199  GTU26001200     Yash Panchal         2
#
# [614 rows x 3 columns]

# %% [markdown]
# # Module 5 - Marks & Department Analysis

# %%
max_per = df['Percentage'].max()
df.loc[df['Percentage'] == max_per,['EnrollmentNo','StudentName','Percentage']]
# Out:
#      EnrollmentNo   StudentName  Percentage
# 1093  GTU26001094  Vivaan Mehta         100

# %%
df.nlargest(10,'Percentage')[['StudentName','Percentage']]
# Out:
#         StudentName  Percentage
# 1093   Vivaan Mehta         100
# 735     Meera Patel          98
# 1098    Rahul Joshi          98
# 889     Kavya Joshi          97
# 917   Dhruv Solanki          97
# 913   Parth Panchal          96
# 361   Dhruv Trivedi          95
# 424     Parth Desai          95
# 426    Aditya Patel          95
# 473     Sneha Mehta          95

# %%
df.groupby('Department').value_counts()
# Out:
# Department  StudentID  EnrollmentNo  StudentName        Gender  Age  City        CollegeName                     Semester  AdmissionDate  Attendance  InternalMarks  PracticalMarks  FinalExamMarks  TotalMarks  Percentage  Grade  Status  FeesTotal  FeesPaid  FeesDue  Scholarship  PlacementStatus  InternshipPerformance  ProjectScore  Backlogs
# Civil       STU0019    GTU26000019   Krishna Chaudhary  Male    23   Patan       Marwadi University              5         2025-07-01     96          23             30              26              79          79          A      Pass    45000      20220     24780    OBC          Seeking Job      Average                83            2           1
#             STU0020    GTU26000020   Aryan Chaudhary    Male    19   Rajkot      LDRP Institute                  5         2025-06-06     86          19             21              26              66          66          B      Pass    30000      13230     16770    SC/ST        Seeking Job      Excellent              52            1           1
#             STU0028    GTU26000028   Harsh Shah         Male    20   Bhavnagar   Silver Oak University           5         2025-10-12     61          21             21              31              73          73          B      Pass    40000      31757     8243     Merit        Placed           Good                   61            0           1
#             STU0030    GTU26000030   Karan Desai        Male    24   Surat       LDRP Institute                  8         2025-12-01     71          24             25              27              76          76          A      Pass    25000      11533     13467    Merit        Higher Studies   Excellent              76            1           1
#             STU0036    GTU26000036   Rahul Solanki      Male    19   Bhavnagar   LDRP Institute                  6         2026-04-17     95          17             18              38              73          73          B      Pass    45000      41240     3760     OBC          Placed           Good                   68            3           1
#                                                                                                                                                                                                                                                                                                                                                         ..
# Mechanical  STU1157    GTU26001157   Sneha Trivedi      Female  19   Himatnagar  SAL College                     8         2025-06-01     93          19             25              21              65          65          B      Pass    35000      19154     15846    OBC          Placed           Excellent              68            0           1
#             STU1159    GTU26001159   Yash Chaudhary     Male    18   Rajkot      Government Engineering College  8         2026-02-27     83          21             21              34              76          76          A      Pass    30000      20731     9269     EWS          Higher Studies   Excellent              92            0           1
#             STU1167    GTU26001167   Aryan Trivedi      Male    20   Mehsana     SAL College                     6         2025-08-24     96          23             25              23              71          71          B      Pass    30000      24420     5580     SC/ST        Higher Studies   Excellent              88            0           1
#             STU1175    GTU26001175   Meera Panchal      Female  20   Junagadh    Ganpat University               7         2025-06-12     98          26             28              20              74          74          B      Pass    35000      20090     14910    SC/ST        Seeking Job      Excellent              85            3           1
#             STU1181    GTU26001181   Ananya Solanki     Female  24   Surat       SAL College                     7         2025-06-11     85          28             20              31              79          79          A      Pass    25000      17802     7198     SC/ST        Seeking Job      Good                   98            0           1
# Name: count, Length: 974, dtype: int64

# %%
df.groupby('Department')['Percentage'].mean()
# Out:
# Department
# Civil                     76.093264
# Computer                  76.746269
# Electrical                75.902703
# Electronics               75.825000
# Information Technology    76.744681
# Mechanical                76.813472
# Name: Percentage, dtype: float64

# %%
df.groupby('Department')[['EnrollmentNo','StudentName']].max()
# Out:
#                        EnrollmentNo   StudentName
# Department
# Civil                   GTU26001198  Yash Trivedi
# Computer                GTU26001200  Yash Trivedi
# Electrical              GTU26001191  Yash Trivedi
# Electronics             GTU26001199  Yash Trivedi
# Information Technology  GTU26001192  Yash Trivedi
# Mechanical              GTU26001184  Yash Solanki

# %%
df.groupby('Department')['Attendance'].sum().reset_index()
# Out:
#                Department  Attendance
# 0                   Civil       15193
# 1                Computer       16054
# 2              Electrical       14821
# 3             Electronics       18926
# 4  Information Technology       14876
# 5              Mechanical       15766

# %%
df.groupby('Department')['ProjectScore'].mean().reset_index()
# Out:
#                Department  ProjectScore
# 0                   Civil     72.575130
# 1                Computer     74.805970
# 2              Electrical     74.172973
# 3             Electronics     74.083333
# 4  Information Technology     74.904255
# 5              Mechanical     75.575130

# %% [markdown]
# # Module 7 - College Analysis

# %%
df['CollegeName'].value_counts()
# Out:
# CollegeName
# Ganpat University                 163
# LJ University                     157
# Alpha College                     155
# Government Engineering College    154
# LDRP Institute                    151
# SAL College                       149
# Silver Oak University             137
# Marwadi University                134
# Name: count, dtype: int64

# %%
df.groupby('CollegeName')['FeesTotal'].sum()
# Out:
# CollegeName
# Alpha College                     5510000
# Ganpat University                 5755000
# Government Engineering College    5445000
# LDRP Institute                    5290000
# LJ University                     5365000
# Marwadi University                4630000
# SAL College                       5210000
# Silver Oak University             4890000
# Name: FeesTotal, dtype: int64

# %% [markdown]
# # Module 8

# %%
count_city_wise =df.groupby('City')['StudentName'].count()

# %%
count_city_wise.nlargest(5)
# Out:
# City
# Bhavnagar    127
# Vadodara     124
# Ahmedabad    123
# Junagadh     123
# Surat        120
# Name: StudentName, dtype: int64

# %%
df.groupby('City')['Attendance'].mean().round(2).sort_values().reset_index()
# Out:
#           City  Attendance
# 0  Gandhinagar       77.39
# 1     Vadodara       78.84
# 2       Rajkot       78.87
# 3    Ahmedabad       79.62
# 4        Surat       79.72
# 5      Mehsana       79.83
# 6     Junagadh       80.28
# 7        Patan       80.72
# 8   Himatnagar       80.78
# 9    Bhavnagar       80.88

# %%
df.sort_values(by='TotalMarks',ascending=False).drop_duplicates(subset='City')[['City','StudentName','TotalMarks']]
# Out:
#              City       StudentName  TotalMarks
# 1093     Vadodara      Vivaan Mehta         100
# 1098    Ahmedabad       Rahul Joshi          98
# 735      Junagadh       Meera Patel          98
# 917     Bhavnagar     Dhruv Solanki          97
# 889         Surat       Kavya Joshi          97
# 1084  Gandhinagar       Aarav Mehta          95
# 790        Rajkot        Nisha Shah          94
# 456    Himatnagar      Ishita Joshi          93
# 12        Mehsana  Ishita Prajapati          91
# 454         Patan     Aarav Panchal          90

# %% [markdown]
# # Module 9

# %%
df.loc[df['Attendance'] <= 75 , ['Attendance','StudentName']]
# Out:
#       Attendance    StudentName
# 0             63   Vivaan Desai
# 1             62   Ananya Mehta
# 8             63    Aryan Desai
# 10            72    Dhruv Joshi
# 13            67  Rahul Panchal
# ...          ...            ...
# 1188          62    Nisha Joshi
# 1190          66   Yash Trivedi
# 1191          72  Aryan Trivedi
# 1193          62    Ananya Shah
# 1195          61    Rahul Joshi
#
# [479 rows x 2 columns]

# %%
df.groupby('Department')['Attendance'].value_counts()
# Out:
# Department  Attendance
# Civil       64            10
#             86             9
#             61             7
#             62             7
#             78             7
#                           ..
# Mechanical  79             2
#             82             2
#             64             1
#             67             1
#             87             1
# Name: count, Length: 246, dtype: int64

# %% [markdown]
# # Module 10

# %%
df['FeesTotal'].sum()
# Out:
# np.int64(42095000)

# %%
df.nlargest(20,'FeesTotal')[['StudentName','FeesTotal']]
# Out:
#           StudentName  FeesTotal
# 1        Ananya Mehta      45000
# 8         Aryan Desai      45000
# 13      Rahul Panchal      45000
# 16   Ananya Prajapati      45000
# 18  Krishna Chaudhary      45000
# 31        Kavya Joshi      45000
# 32         Meera Shah      45000
# 35      Rahul Solanki      45000
# 37      Aryan Solanki      45000
# 38        Rahul Joshi      45000
# 42        Vivaan Shah      45000
# 43          Yash Shah      45000
# 50        Aarav Mehta      45000
# 56     Ananya Trivedi      45000
# 65        Parth Desai      45000
# 75      Kavya Solanki      45000
# 76     Ananya Panchal      45000
# 83         Yash Patel      45000
# 88      Sneha Solanki      45000
# 89          Riya Shah      45000

# %%
df.columns
# Out:
# Index(['StudentID', 'EnrollmentNo', 'StudentName', 'Gender', 'Age', 'City',
#        'CollegeName', 'Department', 'Semester', 'AdmissionDate', 'Attendance',
#        'InternalMarks', 'PracticalMarks', 'FinalExamMarks', 'TotalMarks',
#        'Percentage', 'Grade', 'Status', 'FeesTotal', 'FeesPaid', 'FeesDue',
#        'Scholarship', 'PlacementStatus', 'InternshipPerformance',
#        'ProjectScore', 'Backlogs'],
#       dtype='object')

# %% [markdown]
# # Module 11 - Placement Analysis

# %%
df['PlacementStatus'].value_counts()['Placed']
# Out:
# np.int64(401)

# %%
df['PlacementStatus'].value_counts()['Seeking Job']
# Out:
# np.int64(399)

# %%
df['PlacementStatus'].value_counts(normalize=True) * 100
# Out:
# PlacementStatus
# Placed            33.416667
# Higher Studies    33.333333
# Seeking Job       33.250000
# Name: proportion, dtype: float64

# %%
df.groupby('Department')['PlacementStatus'].value_counts()
# Out:
# Department              PlacementStatus
# Civil                   Seeking Job        68
#                         Higher Studies     64
#                         Placed             61
# Computer                Seeking Job        69
#                         Placed             67
#                         Higher Studies     65
# Electrical              Higher Studies     64
#                         Placed             61
#                         Seeking Job        60
# Electronics             Higher Studies     83
#                         Placed             82
#                         Seeking Job        75
# Information Technology  Placed             67
#                         Higher Studies     62
#                         Seeking Job        59
# Mechanical              Seeking Job        68
#                         Placed             63
#                         Higher Studies     62
# Name: count, dtype: int64

# %% [markdown]
# # Module 12 - Scholarship Analysis

# %%
df['Scholarship'].notna().sum()
# Out:
# np.int64(974)

# %%
df.groupby('Scholarship')['StudentName'].value_counts()
# Out:
# Scholarship  StudentName
# EWS          Harsh Trivedi     4
#              Kavya Patel       4
#              Parth Mehta       4
#              Aditya Mehta      3
#              Aditya Panchal    3
#                               ..
# SC/ST        Yash Desai        1
#              Yash Mehta        1
#              Yash Patel        1
#              Yash Prajapati    1
#              Yash Solanki      1
# Name: count, Length: 571, dtype: int64

# %%
df.groupby('Scholarship')[['StudentName','PlacementStatus']].value_counts()
# Out:
# Scholarship  StudentName     PlacementStatus
# EWS          Karan Trivedi   Placed             3
#              Priya Joshi     Placed             3
#              Riya Joshi      Seeking Job        3
#              Aditya Panchal  Placed             2
#              Aryan Desai     Seeking Job        2
#                                                ..
# SC/ST        Yash Prajapati  Placed             1
#              Yash Solanki    Seeking Job        1
#              Yash Trivedi    Higher Studies     1
#                              Placed             1
#                              Seeking Job        1
# Name: count, Length: 799, dtype: int64

# %% [markdown]
# # Module 13

# %%
df['InternshipPerformance'].value_counts()
# Out:
# InternshipPerformance
# Good         319
# Average      302
# Very Good    298
# Excellent    281
# Name: count, dtype: int64

# %%
df['ProjectScore'].mean()
# Out:
# np.float64(74.34416666666667)

# %%
df.loc[df['ProjectScore'] == df['ProjectScore'].max(), ['StudentName', 'ProjectScore']].sort_values(by='ProjectScore', ascending=False)
# Out:
#           StudentName  ProjectScore
# 74          Riya Shah           100
# 82          Yash Shah           100
# 108   Aarav Prajapati           100
# 156     Rahul Panchal           100
# 205       Harsh Desai           100
# 258       Aarav Desai           100
# 282    Vivaan Solanki           100
# 288     Krishna Patel           100
# 443      Aditya Desai           100
# 504   Krishna Trivedi           100
# 538   Priya Prajapati           100
# 808   Krishna Trivedi           100
# 878      Ananya Patel           100
# 883       Ishita Shah           100
# 885   Karan Chaudhary           100
# 947   Harsh Chaudhary           100
# 991      Ananya Joshi           100
# 1059     Yash Solanki           100
# 1126      Karan Mehta           100
# 1128  Nisha Prajapati           100
# 1168     Vivaan Joshi           100

# %% [markdown]
# # Module 14 – Visualization using Matplotlib

# %%
# Create a bar chart of department-wise students.

import matplotlib.pyplot as plt 

department_counts = df['Department'].value_counts()

department_counts.plot(kind='pie', color='steelblue',autopct='%1.1f%%')

plt.title('Students by Department')
plt.xlabel('Department')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a line chart of average percentage by department
department_counts = df['Department'].value_counts()
dept_avg = df.groupby('Department')['Percentage'].mean()

dept_avg.plot(
    kind='line',
    marker='o',
    color='steelblue',
    figsize=(10, 6)
)

plt.title('Students by Department')
plt.xlabel('Department')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
# Create a histogram of percentages.

df['Percentage'].plot(kind='hist', bins=20, color='red',edgecolor = "black" , figsize=(10,6))
plt.title('Students by Percentages')
plt.xlabel('Percentage')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
# Create a pie chart for gender distribution.
gender_counts = df['Gender'].value_counts()

gender_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=['steelblue', 'lightcoral'],
    startangle=90
)
plt.title('Gender Distribution')
plt.tight_layout()
plt.show()

# %%
# Create a scatter plot between Attendance and Percentage.
plt.figure(figsize=(10, 6))

plt.scatter(
    df['Attendance'],
    df['Percentage'],
    c=df['Attendance'],
    cmap='inferno',
    label='Students'
)
plt.colorbar(label='Attendance')
plt.title('Attendance vs Percentage')
plt.xlabel('Attendance')
plt.ylabel('Percentage')
plt.legend()
plt.show()

# %%
df['Status'] = df['Percentage'].ge(60).map({
    True: 'Pass',
    False: 'Fail'
})

# %%
plt.figure(figsize=(10, 6))
counts = df.groupby('Department')['Status'].value_counts().unstack(fill_value=0)

Pass = counts['Pass'].ge(60)
Fail = counts['Fail'].lt(60)

plt.stackplot(
    counts.index,
    Pass.astype(int),
    Fail.astype(int),
    labels=['Pass', 'Fail']
    
)

plt.legend(loc='upper right')
plt.xlabel('Department')
plt.ylabel('Pass / Fail')
plt.grid()
plt.show()
